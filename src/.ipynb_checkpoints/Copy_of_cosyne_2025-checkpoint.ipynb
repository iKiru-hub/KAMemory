# %% [markdown]
# ### setup

# %%
# !wget -q https://raw.githubusercontent.com/tsunrise/colab-github/main/colab_github.py
import colab_github
colab_github.github_auth(persistent_key=True)


# !git clone https://github.com/iKiru-hub/KAMemory

# !git config --global user.email "albert.albesa.gonzalez@gmail.com"
# !git config --global user.name "albesagonzalez"
# %cd KAMemory/


# !pip install coloredlogs
# Out:
# Mounted at /content/drive/
# Looks that a private key is already created. If you have already push it to github, no action required.
#  Otherwise, Please go to https://github.com/settings/ssh/new to upload the following key:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAILOvyiaQSiFW9vBkQLcEVONFK/8pgUlMDWsO1gZUY7ne root@ee5b6d5543f0
#
# Please use SSH method to clone repo.
# Cloning into 'KAMemory'...
# remote: Enumerating objects: 4562, done.
# remote: Counting objects: 100% (4562/4562), done.
# remote: Compressing objects: 100% (2425/2425), done.
# remote: Total 4562 (delta 2005), reused 4442 (delta 1891), pack-reused 0 (from 0)
# Receiving objects: 100% (4562/4562), 16.61 MiB | 24.40 MiB/s, done.
# Resolving deltas: 100% (2005/2005), done.
# /content/KAMemory
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 3.4 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/iKiru-hub/KAMemory
# Out:
# Cloning into 'KAMemory'...
# remote: Enumerating objects: 4591, done.
# remote: Total 4591 (delta 0), reused 0 (delta 0), pack-reused 4591 (from 1)
# Receiving objects: 100% (4591/4591), 16.92 MiB | 13.24 MiB/s, done.
# Resolving deltas: 100% (2023/2023), done.

# %%
# !git add .
# !git commit -m "add model weights"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# ### import

# %%
import torch
from torch import nn

import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import os, json
from pprint import pprint

import numpy as np
import matplotlib.pyplot as plt

# %%
from KAMemory.src import utils
# Out:
# /content/KAMemory/src/utils.py:21: UserWarning: coloredlogs not installed
#   warnings.warn("coloredlogs not installed")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-e1f23291bc3e> in <cell line: 1>()
# ----> 1 from KAMemory.src import utils
#
# /content/KAMemory/src/utils.py in <module>
#      25 import json
#      26
# ---> 27 import models
#      28
#      29 # print(f"{__name__}::{ISCOLORED=}")
#
# ModuleNotFoundError: No module named 'models'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### code

# %%
def plot_input(input, network_params):
  mec = input[:network_params["dim_mec"]]
  lec = input[network_params["dim_mec"]:]

  fig, axs = plt.subplots(1, 2, figsize=(12, 12))
  axs[0].imshow(mec.reshape(network_params["mec_N_y"], network_params["mec_N_x"]), cmap='gray_r')
  axs[0].set_title('space')
  lec_width = int(np.sqrt(network_params["dim_lec"]))
  axs[1].imshow(lec.reshape((-1, network_params["dim_lec"])), cmap='gray_r')
  axs[1].set_title('sensory')
  axs[0].set_yticks([])
  axs[1].set_yticks([])
  axs[0].set_xticks([])
  axs[1].set_xticks([])
  plt.show()

# %%
def sparsemoid(z: torch.Tensor, K: int,
               beta: float, flag=False) -> torch.Tensor:

    if K > 0:
        z_sorted = torch.sort(z, descending=True, dim=1).values

        alpha = z_sorted[:, K-1: K+1]
        alpha = alpha.mean(axis=1).reshape(-1, 1)

    # if flag:
    #     print(f"alpha: {alpha.T} {alpha.shape}")
    #     print("sorted ", z_sorted.shape, z_sorted)

    # apply
    z = beta * (z - alpha)
    return torch.sigmoid(z)

# %%
class Autoencoder(nn.Module):

    def __init__(self, dim_input: int=10, dim_lat=10,
                 activation: str=None, K_lat: int=10, beta_lat: float=20.,
                 use_bias: bool=True):

        """
        Simple autoencoder with a single linear layer as encoder and decoder.

        Parameters
        ----------
        input_dim: int
            the size of the input data
        encoding_dim: int
            the size of the encoded data
        K: int
            the number of top values to select.
            Default is 10
        beta: float
            the beta value for the sparsemoid function.
            Default is 20.
        use_bias: bool
            use bias in the linear layers.
            Default is True.
        """

        super(Autoencoder, self).__init__()

        self._input_dim = dim_input
        self._encoding_dim = dim_lat
        self._K_lat= K_lat
        self._beta_lat = beta_lat

        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(dim_input, dim_input, bias=use_bias),
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(dim_lat, dim_input, bias=use_bias),
        )

    def forward(self, x: torch.Tensor, ca1: bool=False):

        """
        Forward pass

        Parameters
        ----------
        x: torch.Tensor
            input data
        ca1: bool
            return the data from CA1. Default is False

        Returns
        -------
        torch.Tensor
            reconstructed data
        """

        z = self.encoder(x)
        z = sparsemoid(z=z, K=self._K_lat,
                             beta=self._beta_lat)

        # ---
        x = self.decoder(z)
        x = torch.sigmoid(x)
        #x = torch.sigmoid(10*(x-0.1))
        #x = sparsemoid(z=x, K=self._K_lat,
        #               beta=self._beta_lat)

        if ca1:
            return x, z

        return x

    def get_weights(self, bias: bool=False):

        """
        Get the weights of the autoencoder model

        Returns
        -------
        tuple
            the weights of the encoder and decoder
        """

        ei_ca1 = self.encoder[0].weight.data.reshape(self._encoding_dim, self._input_dim)
        ca1_eo = self.decoder[0].weight.data.reshape(self._input_dim, self._encoding_dim)

        if bias:
            ei_ca1_b = self.encoder[0].bias.data.reshape(-1, 1)
            ca1_eo_b = self.decoder[0].bias.data.reshape(-1, 1)

            return ei_ca1, ca1_eo, ei_ca1_b, ca1_eo_b

        return ei_ca1, ca1_eo



def sparsemoid(z: torch.Tensor, K: int,
               beta: float, flag=False) -> torch.Tensor:

    if K > 0:
        z_sorted = torch.sort(z, descending=True, dim=1).values

        alpha = z_sorted[:, K-1: K+1]
        alpha = alpha.mean(axis=1).reshape(-1, 1)

    # if flag:
    #     print(f"alpha: {alpha.T} {alpha.shape}")
    #     print("sorted ", z_sorted.shape, z_sorted)

    # apply
    z = beta * (z - alpha)
    return torch.sigmoid(z)


class MTL(nn.Module):

    def __init__(self, W_ei_ca1: torch.Tensor,
                 W_ca1_eo: torch.Tensor,
                 K_lat: int,
                 K_out: int,
                 dim_ca3: int,
                 beta: float,
                 alpha: float=0.01,
                 K_ca3: int=5,
                 identity_IS : bool=False,
                 B_ei_ca1: torch.Tensor=None,
                 B_ca1_eo: torch.Tensor=None):

        # make docstrings
        """
        Multi-target learning model with BTSP learning rule

        Parameters
        ----------
        W_ei_ca1: torch.Tensor
            the weight matrix from entorhinal cortex to CA1
        W_ca1_eo: torch.Tensor
            the weight matrix from CA1 to entorhinal cortex output
        B_ei_ca1: torch.Tensor
            the bias for the EC to CA1 layer.
            Default is None
        B_ca1_eo: torch.Tensor
            the bias for the CA1 to EC output layer.
            Default is None
        K_lat: int
            the number of top values to select
        K_out: int
            the number of top values to select for the output
        K_ca3: int
            the number of top values to select for the CA3 layer
        beta: float
            the beta value for the sparsemoid function
        alpha: float
            the learning rate for the weight update
        dim_ca3: int
            the size of the CA3 layer
        """

        super(MTL, self).__init__()

        # infer dimensions of EC input and output and CA1
        self._dim_ei = W_ei_ca1.shape[1]
        self._dim_eo = W_ca1_eo.shape[0]
        self._dim_ca1 = W_ca1_eo.shape[1]

        # network parameters
        self._K_lat = K_lat
        self._K_ca3 = K_ca3
        self._K_out = K_out
        self._beta = beta
        self._beta_ca3 = 100*beta
        self._alpha = alpha

        # Initialize weight matrices for each layer
        self.W_ei_ca3 = nn.Parameter(torch.randn(dim_ca3,
                                                 self._dim_ei) / dim_ca3)
        self.W_ei_ca1 = nn.Parameter(W_ei_ca1)
        self.W_ca3_ca1 = nn.Parameter(torch.zeros(self._dim_ca1, dim_ca3))
        self.W_ca1_eo = nn.Parameter(W_ca1_eo)

        self.B_ei_ca1 = nn.Parameter(torch.zeros(self._dim_ca1, 1) \
                                    if B_ei_ca1 is None else B_ei_ca1)
        self.B_ca1_eo = nn.Parameter(torch.zeros(self._dim_eo, 1) \
                                    if B_ca1_eo is None else B_ca1_eo)
        self.is_bias = B_ei_ca1 is not None and B_ca1_eo is not None

        self._ca1 = None
        self._ca3 = None
        self._eo = None

        self.identity_IS = identity_IS

        # mode
        self.mode = "train"

        self.recordings = {}
        self.recordings["x_ei"] = []
        self.recordings["ca3"] = []
        self.recordings["IS"] = []
        self.recordings["ca1"] = []
        self.recordings["eo"] = []
        self.recordings["W_ca3_ca1"] = []

    def __repr__(self):

        return f"MTL(dim_ei={self._dim_ei}, dim_ca1={self._dim_ca1}," + \
            f" dim_ca3={self.W_ei_ca3.shape[0]}, dim_eo={self._dim_eo}, " + \
            f" bias={self.is_bias}" + \
            f"beta={self._beta}, alpha={self._alpha}, K_l={self._K_lat}, " + \
            f"K_o={self._K_out}"

    def forward(self, x_ei: torch.Tensor, ca1: bool=False):

        """
        Forward pass

        Parameters
        ----------
        x_ei: torch.Tensor
            input data
        ca1: bool
            return the data from CA1. Default is False

        Returns
        -------
        torch.Tensor
            reconstructed data
        """

        # forward pass through the entorhinal cortex to CA3
        x_ca3 = self.W_ei_ca3 @ x_ei # 50, 1
        x_ca3 = utils.sparsemoid(x_ca3.reshape(1, -1),
                                 K=2,
                                 beta=self._beta_ca3).reshape(-1, 1)

        # forward pass through CA3 to CA1
        x_ca1 = self.W_ca3_ca1 @ x_ca3 # 50, 1
        x_ca1 = utils.sparsemoid(x_ca1.reshape(1, -1),
                                 K=self._K_lat,
                                 beta=self._beta,
                                 flag=False).reshape(-1, 1)

        # compute instructive signal
        if self.identity_IS:
          IS = x_ei
        else:
          IS = self.W_ei_ca1 @ x_ei + self.B_ei_ca1
          IS = utils.sparsemoid(IS.reshape(1, -1), K=self._K_lat,
                                beta=self._beta).reshape(-1, 1)

        # weight update
        if self.mode == "train":
            self.W_ca3_ca1 = nn.Parameter((1 - IS * self._alpha) * \
                self.W_ca3_ca1 + self._alpha * (IS @ x_ca3.T))

        # Forward pass through CA1 to entorhinal cortex output
        x_eo = self.W_ca1_eo @ x_ca1 + self.B_ca1_eo

        # activation function
        x_eo = utils.sparsemoid(x_eo.reshape(1, -1),
                                K=self._K_out,
                                beta=self._beta).reshape(-1, 1)

        self._ca1 = x_ca1
        self._ca3 = x_ca3
        self._eo = x_eo

        self.record(x_ei, IS)
        if ca1:
            return x_eo, x_ca1




        return x_eo

    def pause_lr(self):

        """
        Pause learning rate
        """

        self.mode = "test"

    def resume_lr(self):

        """
        Resume learning rate
        """

        self.mode = "train"

    def record(self, x_ei, IS):
        self.recordings["x_ei"].append(x_ei.clone())
        self.recordings["ca3"].append(self._ca3.clone())
        self.recordings["ca1"].append(self._ca1.clone())
        self.recordings["eo"].append(self._eo.clone())
        self.recordings["W_ca3_ca1"].append(self.W_ca3_ca1.clone())
        self.recordings["IS"].append(IS.clone())

# %%
def sparse_stimulus_generator(num_stimuli: int, K : int,
                              mec_size: int,  lec_size: int, N_x : int, N_y : int, pf_sigma: int, position_list=None,
                              cue_position=None, sen_list=None, plot: bool=False) -> np.ndarray:

    """
    This function generates random z patterns with a certain
    degree of sparsity

    Parameters
    ----------
    N : int
        Number of samples
    K : int
        Number of active units
    size : int, optional
        Size of the z patterns, by default 10
    plot : bool, optional
        Whether to plot the z patterns.
        Default False

    Returns
    -------
    samples : np.ndarray
        z patterns
    """

    def place_field_activity(N_x, N_y, sigma, xi, yi):

      """
      Computes place field activity for each cell on an NxN grid for a given location (xi, yi).
      """

      def circular_distance(x1, x2, N):
        """
        Computes the minimum circular distance in the x-direction (wraps around the boundaries).
        """
        return np.minimum(np.abs(x1 - x2), N - np.abs(x1 - x2))

      # Create a grid of size NxN with place cells at each position
      x = np.linspace(0, N_x-1, N_x)
      y = np.linspace(0, N_y-1, N_y)
      X, Y = np.meshgrid(x, y)
      # Calculate the squared Euclidean distance between (xi, yi) and each place cell location
      dist_squared = circular_distance(X, xi, N_x) ** 2 + (Y - yi) ** 2

      # Compute Gaussian activity for each place cell
      activity = np.exp(-dist_squared / (2 * sigma ** 2))
      return activity


    samples = np.zeros((num_stimuli, mec_size + lec_size))

    if lec_size > 0:
      fixed_cue = np.zeros((lec_size))
      cue_idx = np.random.choice(range(lec_size), replace=False, size=K)
      fixed_cue[cue_idx] = 1
    for i in range(num_stimuli):
      if mec_size > 0:
        x_i, y_i = (position_list[i] if position_list is not None else (np.random.randint(0, N_x), np.random.randint(0, N_y)))
        activity_grid = place_field_activity(N_x, N_y, pf_sigma, x_i, y_i)
        samples[i, :mec_size] = activity_grid.flatten()
      if lec_size > 0:
        if cue_position is not None:
          if x_i == cue_position:
            activity_lec = fixed_cue
          else:
            activity_lec = np.zeros((lec_size))
            lec_idx = np.random.choice(range(lec_size), replace=False, size=K)
            activity_lec[lec_idx] = 1
          samples[i, mec_size:] = sen_list[i] if sen_list is not None else activity_lec

    samples = samples.astype(np.float32)

    return samples

# %%
network_params = {}

network_params["mec_N_x"] = 50
network_params["mec_N_y"] = 1
network_params["dim_mec"] = network_params["mec_N_x"]*network_params["mec_N_y"]
network_params["mec_sigma"] = 7
network_params["dim_lec"] = 50

network_params["dim_ei"] = network_params["dim_mec"] + network_params["dim_lec"]
network_params["dim_ca3"] = 100
network_params["dim_ca1"] = 100
network_params["dim_eo"] = network_params["dim_ei"]

network_params["K_lec"] = 5
network_params["K_ei"] = 10
network_params["K_ca3"] = 10
network_params["K_ca1"] = 20
network_params["K_eo"] = network_params["K_ei"]

network_params["beta_ei"] = 150
network_params["beta_ca3"] = 150
network_params["beta_ca1"] = 150
network_params["beta_eo"] =network_params["beta_ei"]

# %%
# autoencoder
autoencoder = Autoencoder(dim_input=network_params["dim_ei"],
                          dim_lat=network_params["dim_ca1"],
                          K_lat=network_params["K_ca1"],
                          beta_lat=network_params["beta_ca1"])


""" make data """

num_train_stimuli = 512
num_test_stimuli = 512

training_samples = sparse_stimulus_generator(num_stimuli=num_train_stimuli,
                                                K = network_params["K_lec"],
                                                mec_size=network_params["dim_mec"],
                                                lec_size=network_params["dim_lec"],
                                                N_x=network_params["mec_N_x"],
                                                N_y=network_params["mec_N_y"],
                                                pf_sigma=network_params["mec_sigma"],
                                                position_list =None,
                                                cue_position=None,
                                                sen_list=None,
                                                plot=False)

test_samples = sparse_stimulus_generator(num_stimuli=num_test_stimuli,
                                                K = network_params["K_lec"],
                                                mec_size=network_params["dim_mec"],
                                                lec_size=network_params["dim_lec"],
                                                N_x=network_params["mec_N_x"],
                                                N_y=network_params["mec_N_y"],
                                                pf_sigma=network_params["mec_sigma"],
                                                position_list=None,
                                                cue_position=None,
                                                sen_list=None,
                                                plot=False)

# %%
epochs = 300
loss_ae, autoencoder = utils.train_autoencoder(
                training_data=training_samples,
                test_data=test_samples,
                model=autoencoder,
                epochs=int(epochs),
                batch_size=64, learning_rate=1e-3)

loss_ae, autoencoder = utils.train_autoencoder(
                training_data=training_samples,
                test_data=test_samples,
                model=autoencoder,
                epochs=int(epochs),
                batch_size=64, learning_rate=5e-4)
# Out:
# ...
# Epoch [300], Loss: 0.0000, Test: 0.0000: 100%|██████████| 300/300 [01:17<00:00,  3.85it/s]

# %%
network_params["alpha"] = 0.8

W_ei_ca1, W_ca1_eo, B_ei_ca1, B_ca1_eo = autoencoder.get_weights(bias=True)


model = MTL(W_ei_ca1=W_ei_ca1,
            W_ca1_eo=W_ca1_eo,
            B_ei_ca1=B_ei_ca1,
            B_ca1_eo=B_ca1_eo,
            dim_ca3=network_params["dim_ca3"],
            K_lat=network_params["K_ca1"],
            K_out=network_params["K_eo"],
            K_ca3=network_params["K_ca3"],
            beta=network_params["beta_ca1"],
            alpha=network_params["alpha"],
            identity_IS=False
            )

# %%
def get_track_input(tp):
  position_list = [(x, 0) for lap in range(tp["num_laps"]) for x in range(tp["length"])]

  if tp["reward"] == "random":
    reward_list = None
  if tp["cue"] == "random":
    cue_list = None

  sen_list = None

  track_input = sparse_stimulus_generator(num_stimuli=tp["num_laps"]*tp["length"],
                                                K = network_params["K_lec"],
                                                mec_size=network_params["dim_mec"],
                                                lec_size=network_params["dim_lec"],
                                                N_x=network_params["mec_N_x"],
                                                N_y=network_params["mec_N_y"],
                                                pf_sigma=network_params["mec_sigma"],
                                                position_list=position_list,
                                                cue_position=tp["cue_position"],
                                                sen_list=None,
                                                plot=False)
  return track_input

# %%
track_params = {}
track_params["length"] = network_params["mec_N_x"]
track_params["num_laps"] = 100
track_params["reward"] = "random"
track_params["cue"] = "random"
track_params["cue_position"] = 25

track_train_input = get_track_input(track_params)

# %%
track_train_input.shape
# Out:
# (5000, 100)

# %%
# train model | testing = training without backprop
epochs = 1
for _ in range(epochs):
    _, model = utils.testing(data=track_train_input,
                              model=model,
                              column=True)
'''
    loss_mtl, _ = utils.testing(data=track_train_input,
                                model=model,
                                column=True)
'''
# Out:
# '\n    loss_mtl, _ = utils.testing(data=track_train_input,\n                                model=model,\n                                column=True)\n'

# %%
activity = np.array(model.recordings["ca1"]).reshape((track_params["num_laps"], track_params["length"], -1))

# %%
activity = np.array(model.recordings["IS"]).reshape((track_params["num_laps"], track_params["length"], -1))

# %%
activity = np.array(model.recordings["x_ei"]).reshape((track_params["num_laps"], track_params["length"], -1))

# %%
activity = np.array(model.recordings["ca3"]).reshape((track_params["num_laps"], track_params["length"], -1))

# %%
plot_input(model.recordings["x_ei"][1], network_params)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-90-3afb2e8576da> in <cell line: 1>()
# ----> 1 plot_input(model.recordings["x_ei"][1], network_params)
#
# <ipython-input-5-b0f580ab6d09> in plot_input(input, network_params)
#       7   axs[0].set_title('space')
#       8   lec_width = int(np.sqrt(network_params["dim_lec"]))
# ----> 9   axs[1].imshow(lec.reshape((-1, network_params["dim_lec"])), cmap='gray_r')
#      10   axs[1].set_title('sensory')
#      11   axs[0].set_yticks([])
#
# RuntimeError: cannot reshape tensor of 0 elements into shape [-1, 0] because the unspecified dimension size -1 can be any value and is ambiguous

# %%
activity_mean = np.mean(activity, axis=0)
np.argmax(activity_mean, axis=0).shape
# Out:
# (200,)

# %%
np.array(model.recordings["x_ei"]).reshape((100, 50, -1)).shape
# Out:
# (100, 100, 100)

# %%
np.array(model.recordings["IS"]).shape
# Out:
# (10000, 100, 1)

# %%
plt.hist(preferential_fields.flatten(), bins=50)
plt.xlim([0, 50])
# Out:
# (0.0, 50.0)

# %%
plt.hist(preferential_fields.flatten(), bins=50)
plt.xlim([0, 50])
# Out:
# (0.0, 50.0)

# %%
# Assuming 'activity' is a 3D array of shape (laps, positions, neurons)
# activity.shape = (n_laps, n_positions, n_neurons)

# Step 1: Average across laps (axis 0)
activity_mean = np.mean(activity, axis=0)  # Now shape is (positions, neurons)

# Step 2: Find preferential place field (position with max activity) for each neuron
preferential_fields = np.argmax(activity_mean, axis=0)  # Finds the max position for each neuron

# Step 3: Sort neurons by preferential place fields in descending order
sorted_indices = np.argsort(preferential_fields)[::-1]  # Sort in descending order of place fields
sorted_activity = activity_mean[:, sorted_indices]  # Reorder neurons by sorted indices

# Step 4: Plot the heatmap
plt.figure(figsize=(10, 8))
plt.imshow(sorted_activity.T, aspect='auto', cmap='hot', interpolation='nearest')
plt.colorbar(label='Activity (Averaged over laps)')
plt.ylabel('Neurons (sorted by place field)')
plt.xlabel('Position on track')
plt.title('CA1 Neuron Activity Sorted by Preferential Place Fields')
plt.show()

# %%
plot_input(model.recordings["ca1"][55], network_params)

# %%
out_ae, latent_ae = utils.reconstruct_data(data=track_train_input,
                                num=num_btsp_samples,
                                model=autoencoder,
                                show=False,
                                plot=False)

# train model | testing = training without backprop
epochs = 1
for _ in range(epochs):
    _, model = utils.testing(data=training_btsp_samples,
                              model=model,
                              column=True)

    loss_mtl, _ = utils.testing(data=training_btsp_samples,
                                model=model,
                                column=True)

# reconstruct data
model.pause_lr()
out_mtl, latent_mtl = utils.reconstruct_data(
                  data=training_btsp_samples,
                  num=num_btsp_samples,
                  model=model,
                  column=True,
                  plot=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-9e7516f15105> in <cell line: 1>()
# ----> 1 out_ae, latent_ae = utils.reconstruct_data(data=training_btsp_samples,
#       2                                 num=num_btsp_samples,
#       3                                 model=autoencoder,
#       4                                 show=False,
#       5                                 plot=False)
#
# NameError: name 'training_btsp_samples' is not defined

# %%
plot_input(test_samples[0], network_params)

# %%
# Out:
# Epoch [300], Loss: 0.0010, Test: 0.0145: 100%|██████████| 300/300 [01:09<00:00,  4.30it/s]

# %%
plt.plot(test_loss_curve)

# %%
output, latent = autoencoder(torch.tensor(test_samples), ca1=True)

# %%
plt.hist(latent.flatten().detach())
# Out:
# (array([39704.,   404.,   263.,   272.,   317.,   335.,   259.,   221.,
#           348.,  9077.]),
#  array([0.        , 0.1       , 0.2       , 0.30000001, 0.40000001,
#         0.5       , 0.60000002, 0.69999999, 0.80000001, 0.89999998,
#         1.        ]),
#  <BarContainer object of 10 artists>)

# %%
plot_input(latent[3].detach().numpy(), network_params)
# Out:
# <ipython-input-12-c89a1a58eec9>:6: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   axs[0].imshow(mec.reshape(network_params["mec_N_x"], network_params["mec_N_y"]), cmap='gray_r')
# <ipython-input-12-c89a1a58eec9>:6: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   axs[0].imshow(mec.reshape(network_params["mec_N_x"], network_params["mec_N_y"]), cmap='gray_r')

# %%
plot_input(output[2].detach().numpy(), network_params)
# Out:
# <ipython-input-12-c89a1a58eec9>:6: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   axs[0].imshow(mec.reshape(network_params["mec_N_x"], network_params["mec_N_y"]), cmap='gray_r')
# <ipython-input-12-c89a1a58eec9>:6: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   axs[0].imshow(mec.reshape(network_params["mec_N_x"], network_params["mec_N_y"]), cmap='gray_r')

# %%
torch.save(autoencoder.state_dict(), '/content/KAMemory/autoencoder_weights.pth')

# %%
# !git add .
# !git commit -m "add model weights"
# Out:
# [main 4830228] add model weights
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  rewrite autoencoder_weights.pth (94%)

# %%
# !git remote set-url origin https://albesagonzalez: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@github.com/iKiru-hub/KAMemory
# !git push origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 292.47 KiB | 11.25 MiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/iKiru-hub/KAMemory
#    631561f..4830228  main -> main

# %%
model = Autoencoder(dim_input=network_params["dim_ei"],
                          dim_lat=network_params["dim_ca1"],
                          K_lat=network_params["K_ca1"],
                          beta_lat=network_params["beta_ca1"])
# Assuming 'model' is your neural network instance
model.load_state_dict(torch.load('/content/KAMemory/autoencoder_weights.pth'))
# Out:
# <ipython-input-23-8dfff1638063>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/content/KAMemory/autoencoder_weights.pth'))
# ...

# %%
plot_input(test_samples[36], network_params)

# %%
plot_input(autoencoder(torch.tensor(test_samples))[36].detach().numpy(), network_params)

# %%
W_ei_ca1, W_ca1_eo, B_ei_ca1, B_ca1_eo = autoencoder.get_weights(bias=True)




model = MTL(W_ei_ca1=W_ei_ca1,
            W_ca1_eo=W_ca1_eo,
            B_ei_ca1=B_ei_ca1,
            B_ca1_eo=B_ca1_eo,
            dim_ca3=network_params["dim_ca3"],
            K_lat=network_params["K_ca1"],
            K_out=network_params["K_eo"],
            K_ca3=network_params["K_ca3"],
            beta=network_params["beta_ca1"],
            alpha=network_params["alpha"],
            )

# %%
num_btsp_samples = 5
#position_list = [(5, 5) for sample in range(num_btsp_samples)]

sen_cue = np.zeros((network_params["dim_lec"]))
cue_idx = np.random.choice(range(network_params["dim_lec"]), replace=False, size=network_params["K_ei"])
sen_cue[cue_idx] = 1
#sen_list = [sen_cue for sample in range(num_btsp_samples)]
sen_list = None

training_btsp_samples = sparse_stimulus_generator(num_stimuli=num_btsp_samples,
                                                K = network_params["K_ei"],
                                                mec_size=network_params["dim_mec"],
                                                lec_size=network_params["dim_lec"],
                                                N_x=network_params["mec_N_x"],
                                                N_y=network_params["mec_N_y"],
                                                pf_sigma=network_params["mec_sigma"],
                                                position_list = None,
                                                sen_list = sen_list,
                                                plot=False)

# %%
plot_input(training_btsp_samples[2], network_params)
# Out:
# <ipython-input-12-c89a1a58eec9>:6: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   axs[0].imshow(mec.reshape(network_params["mec_N_x"], network_params["mec_N_y"]), cmap='gray_r')
# <ipython-input-12-c89a1a58eec9>:6: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   axs[0].imshow(mec.reshape(network_params["mec_N_x"], network_params["mec_N_y"]), cmap='gray_r')

# %%
out_ae, latent_ae = utils.reconstruct_data(data=training_btsp_samples,
                                num=num_btsp_samples,
                                model=autoencoder,
                                show=False,
                                plot=False)

# train model | testing = training without backprop
epochs = 1
for _ in range(epochs):
    _, model = utils.testing(data=training_btsp_samples,
                              model=model,
                              column=True)

    loss_mtl, _ = utils.testing(data=training_btsp_samples,
                                model=model,
                                column=True)

# reconstruct data
model.pause_lr()
out_mtl, latent_mtl = utils.reconstruct_data(
                  data=training_btsp_samples,
                  num=num_btsp_samples,
                  model=model,
                  column=True,
                  plot=False)
# Out:
# ...
# 100%|██████████| 5/5 [00:00<00:00, 808.46it/s]

# %%
time_index = 1

# Example synaptic weights matrix
weights = model.recordings["W_ca3_ca1"][time_index].T
activity_pre = model.recordings["ca3"][time_index]
instructive_post = model.recordings["IS"][time_index]


# Get the number of presynaptic and postsynaptic neurons
num_presynaptic, num_postsynaptic = weights.shape

# Create a figure
plt.figure(figsize=(5, 4))

# Plot presynaptic neurons on the left vertical axis
for i in range(num_presynaptic):
    plt.plot([0], [i], 'ro', markersize=10*activity_pre[i])  # Red dots for presynaptic neurons

# Plot postsynaptic neurons on the right vertical axis
for j in range(num_postsynaptic):
    plt.plot([1], [j], 'bo', markersize=10*instructive_post[j])  # Blue dots for postsynaptic neurons

# Add lines connecting presynaptic and postsynaptic neurons
for i in range(num_presynaptic):
    for j in range(num_postsynaptic):
        # The line width is proportional to the weight
        plt.plot([0, 1], [i, j], 'k-', linewidth=weights[i, j] * 5)  # 'k-' is black line

# Add labels for clarity
#plt.text(-0.15, 4, 'Presynaptic Neurons', ha='center', va='center', fontsize=12, rotation=90)
#plt.text(1.15, 4, 'Postsynaptic Neurons', ha='center', va='center', fontsize=12, rotation=90)

# Remove x-ticks and x-axis labels
#plt.xticks(np.arange(16))
plt.yticks(np.arange(16))

# Show the plot
plt.show()

# %%
num_postsynaptic
# Out:
# 16

# %%
plt.hist(model.recordings["W_ca3_ca1"][2].flatten().detach().numpy())
# Out:
# (array([236.,   3.,   3.,   0.,   5.,   4.,   0.,   0.,   0.,   5.]),
#  array([0.        , 0.1       , 0.2       , 0.30000001, 0.40000001,
#         0.5       , 0.60000002, 0.69999999, 0.80000001, 0.89999998,
#         1.        ]),
#  <BarContainer object of 10 artists>)

# %%
plt.imshow(model.recordings["ca3"][0].detach().numpy())

# %%
plt.imshow(model.recordings["IS"][5].detach().numpy())
plt.colorbar()

# %%
plt.imshow(model.recordings["W_ca3_ca1"][0].detach().numpy())

# %%
""" plotting """

# --- plot data reconstruction
fig2, (ax12, ax22, ax32) = plt.subplots(3, 1, figsize=(15, 5), sharex=True)
is_squash = False

utils.plot_squashed_data(
    data=training_btsp_samples,
                          ax=ax12,
                          title="Patterns", squash=is_squash)
utils.plot_squashed_data(data=out_ae, ax=ax22,
                          title="Autoencoder",
                          squash=is_squash)
utils.plot_squashed_data(data=out_mtl, ax=ax32,
                          title="MTL", squash=is_squash)

fig2.suptitle(f"Reconstruction of {num_btsp_samples} stimuli",
              fontsize=19)
# Out:
# Text(0.5, 0.98, 'Reconstruction of 5 stimuli')

# %%
# Parameters
N = 100  # Size of the environment (NxN)
sigma = 10  # Standard deviation for the place fields

# Create a grid of size NxN with place cells at each position
x = np.linspace(0, N-1, N)
y = np.linspace(0, N-1, N)
X, Y = np.meshgrid(x, y)



# Example: Compute activity for a given position (xi, yi)
xi, yi = 0, 0  # Example location
activity_grid = place_field_activity(xi, yi, sigma)

# Plot the place field activity
plt.imshow(activity_grid, cmap='hot', origin='lower')
plt.colorbar(label='Place Field Activity')
plt.title(f'Place Field Activity for Location ({xi}, {yi})')
plt.show()
